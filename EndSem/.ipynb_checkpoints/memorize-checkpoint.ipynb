# %% [markdown]
# # Autoencoder Practice

# %%
import numpy as np 
from tensorflow import keras 
from tensorflow.keras import layers

# %%
(x_train, _), (x_test, _) = keras.datasets.mnist.load_data()

# %%
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255

x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

# %%
input_img = keras.Input(shape = (28, 28, 1))
encoded = layers.Flatten()(input_img)
encoded = layers.Dense(64, activation = 'relu')(encoded)
decoded = layers.Dense(784, activation  = 'sigmoid')(encoded)
decoded = layers.Reshape((28, 28, 1))(decoded)

# %%
autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss = 'binary_crossentropy')

# %%
autoencoder.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │          50,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 784)                 │          50,960 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape (Reshape)                    │ (None, 28, 28, 1)           │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 101,200 (395.31 KB)
#  Trainable params: 101,200 (395.31 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.utils import plot_model 
plot_model(autoencoder, to_file = "model.png", show_shapes = True)
# Out:
# You must install graphviz (see instructions at https://graphviz.gitlab.io/download/) for `plot_model` to work.

# %%
autoencoder.fit(x_train, x_train, epochs = 10 , batch_size = 128, shuffle = True, validation_data = (x_test, x_test))
# Out:
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2837 - val_loss: 0.1312
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1233 - val_loss: 0.1019
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0995 - val_loss: 0.0887
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0878 - val_loss: 0.0820
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0814 - val_loss: 0.0782
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0784 - val_loss: 0.0763
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0768 - val_loss: 0.0752
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0756 - val_loss: 0.0745
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0753 - val_loss: 0.0742
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0747 - val_loss: 0.0737

# %%
x_predict = autoencoder.predict(x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
import matplotlib.pyplot as plt 

n = 10
plt.figure(figsize= (20,4))

for i in range(n):
    ax = plt.subplot(2, n, i + 1)
    plt.title("Original")
    plt.imshow(x_test[i])
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    ax = plt.subplot(2, n, i + 1 + n)
    plt.title("Encoded")
    plt.imshow(x_predict[i])
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

# %% [markdown]
# # Denoising (B / W)

# %%
from tensorflow.keras.layers import Dense, Input, LeakyReLU
from tensorflow.keras.models import Model

# %%
from tensorflow.keras.datasets import fashion_mnist

(x_train, _) , (x_test, _) = fashion_mnist.load_data()

# Normalizing 
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255

input_size = np.prod(x_train.shape[1:])

x_train = x_train.reshape((len(x_train), input_size))
x_test = x_test.reshape((len(x_test), input_size))



noise_factor = 0.5

x_train_noisy = x_train + noise_factor * np.random.normal(loc = 0.0, scale = 1.0, size = x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc = 0.0, scale = 1.0, size = x_test.shape)

x_train_noisy = np.clip(x_train_noisy, 0, 1)
x_test_noisy = np.clip(x_test_noisy, 0, 1)

# %%
# Build Model 

# Input
input_layer = Input(shape = (input_size,))

# Encoder 
encoder = Dense(256)(input_layer)
encoder = LeakyReLU(alpha=0.2)(encoder)
# Bottleneck
bottleneck = Dense(128)(encoder)
bottleneck = LeakyReLU(alpha = 0.2)(bottleneck)
# Decoder
decoder = Dense(256)(bottleneck)
decoder = LeakyReLU(alpha = 0.2)(decoder)

# Output
output_layer = Dense(input_size, activation = "sigmoid")(decoder)

autoencoder = Model(inputs = input_layer, outputs = output_layer)
autoencoder.compile(optimizer = "adam", loss = "binary_crossentropy")
autoencoder.fit(x_train_noisy, x_train, epochs = 10, batch_size = 128, shuffle = True, validation_data = (x_test_noisy, x_test))

reconstructed_images = autoencoder.predict(x_test_noisy)
# Out:
# C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.3984 - val_loss: 0.3150
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.3091 - val_loss: 0.3046
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.2995 - val_loss: 0.2998
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.2954 - val_loss: 0.2969
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.2924 - val_loss: 0.2950
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.2908 - val_loss: 0.2934
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.2889 - val_loss: 0.2927
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.2877 - val_loss: 0.2917
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2869 - val_loss: 0.2915
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2851 - val_loss: 0.2910
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %%
# Plotting 
import matplotlib.pyplot as plt

n = 10

plt.figure(figsize = (20,9))

for i in range(n):
    ax = plt.subplot(3, n, i + 1)
    plt.title("Original")
    plt.imshow(x_test[i].reshape(28,28))
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    ax = plt.subplot(3, n, i + 1 + n)
    plt.title("Noisy")
    plt.imshow(x_test_noisy[i].reshape(28,28))
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    ax = plt.subplot(3, n, i + 1 + n * 2)
    plt.title("Reconstructed")
    plt.imshow(reconstructed_images[i].reshape(28,28))
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()

# %% [markdown]
# # Denoising ( Color )

# %%
import numpy as np 
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.layers import Dense, Input, ELU
from tensorflow.keras.models import Model

# %%
# Load Data

(x_train, _), (x_test, _) = cifar10.load_data()


# Normalize and Flatten Images 

x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

input_size = np.prod(x_train.shape[1:]).astype("int")

x_train = np.reshape(x_train, (len(x_train), input_size))
x_test = np.reshape(x_test, (len(x_test), input_size))

noise_factor = 0.5

x_train_noisy = x_train + noise_factor * np.random.normal(loc = 0, scale = 1, size = x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc = 0, scale = 1, size = x_test.shape)

x_train_noisy = np.clip(x_train_noisy, 0, 1)
x_test_noisy = np.clip(x_test_noisy, 0, 1)


# Building Autoencoder 

# Input Layer
input_layer = Input(shape = (input_size,))

# Encoding
encoder = Dense(512)(input_layer)
encoder = LeakyReLU(alpha = 0.2)(encoder)

# Bottleneck 
bottleneck = Dense(256)(encoder)
bottleneck = LeakyReLU(alpha = 0.2)(bottleneck)

# Decoder
decoder = Dense(512)(bottleneck)
decoder = LeakyReLU(alpha = 0.2)(decoder)

# Output
output_layer = Dense(input_size, activation = "sigmoid")(decoder)

autoencoder = Model(inputs = input_layer, outputs = output_layer)
autoencoder.compile(optimizer = "adam", loss = "binary_crossentropy")
autoencoder.fit(x_train_noisy, x_train, epochs = 10, batch_size = 128, shuffle = True, validation_data = (x_test_noisy, x_test))

reconstructed_images = autoencoder.predict(x_test_noisy)
# Out:
# Epoch 1/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 16s 39ms/step - loss: 0.6480 - val_loss: 0.6079
# Epoch 2/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 15s 38ms/step - loss: 0.6014 - val_loss: 0.5924
# Epoch 3/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 15s 39ms/step - loss: 0.5909 - val_loss: 0.5890
# Epoch 4/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 15s 39ms/step - loss: 0.5872 - val_loss: 0.5889
# Epoch 5/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 15s 39ms/step - loss: 0.5852 - val_loss: 0.5861
# Epoch 6/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 15s 39ms/step - loss: 0.5841 - val_loss: 0.5850
# Epoch 7/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 15s 39ms/step - loss: 0.5826 - val_loss: 0.5871
# Epoch 8/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 15s 39ms/step - loss: 0.5821 - val_loss: 0.5838
# Epoch 9/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 15s 39ms/step - loss: 0.5817 - val_loss: 0.5839
# Epoch 10/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 15s 38ms/step - loss: 0.5809 - val_loss: 0.5838
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
from matplotlib import pyplot as plt 

n = 10 

plt.figure(figsize = (20, 6))

for i in range(n):
    ax = plt.subplot(3, n, i + 1)
    plt.title("Original")
    plt.imshow(x_test[i].reshape(32, 32, 3))
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    
    ax = plt.subplot(3, n, i + 1 + n)
    plt.title("Noisy")
    plt.imshow(x_test_noisy[i].reshape(32, 32, 3))
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    ax = plt.subplot(3, n, i + 1)

    ax = plt.subplot(3, n, i + 1 + n*2)
    plt.title("Output")
    plt.imshow(reconstructed_images[i].reshape(32, 32, 3))
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

# %% [markdown]
# # CNN

# %%
import tensorflow as tf 
from tensorflow.keras import layers, models 
import numpy as np 
import matplotlib.pyplot as plt

# %%
(X_train, y_train) , (X_test, y_test) = keras.datasets.cifar10.load_data()

# Normalize

X_train = X_train.astype("float32") / 255
X_test = X_test.astype("float32") / 255

# Unoptimized 

cnn_unoptimized = models.Sequential(
    [
        layers.Conv2D(filters = 64, kernel_size = (3, 3), activation = "relu", input_shape = (32, 32, 3)),
        layers.MaxPooling2D((2,2)),
        layers.Conv2D(filters = 64, kernel_size = (3,3), activation = "relu"),
        layers.MaxPooling2D((2,2)),
        layers.Flatten(),
        layers.Dense(64, activation = "relu"),
        layers.Dense(10, activation = "softmax")
    ]
)


cnn_unoptimized.compile(optimizer = "adam", loss = "sparse_categorical_crossentropy", metrics = ["accuracy"])

history = cnn_unoptimized.fit(X_train, y_train, epochs = 10, validation_data = (X_test, y_test))


plt.figure()
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label = 'Training Accuracy')
plt.plot(history.history['val_accuracy'], label = 'Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label = 'Training Loss')
plt.plot(history.history['val_loss'], label = 'Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
# Out:
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 12ms/step - accuracy: 0.3888 - loss: 1.6831 - val_accuracy: 0.5764 - val_loss: 1.2048
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.6000 - loss: 1.1465 - val_accuracy: 0.6386 - val_loss: 1.0381
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.6520 - loss: 0.9889 - val_accuracy: 0.6448 - val_loss: 1.0085
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.6866 - loss: 0.8940 - val_accuracy: 0.6710 - val_loss: 0.9616
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 11ms/step - accuracy: 0.7132 - loss: 0.8259 - val_accuracy: 0.6872 - val_loss: 0.9063
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.7324 - loss: 0.7709 - val_accuracy: 0.6861 - val_loss: 0.9021
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.7463 - loss: 0.7308 - val_accuracy: 0.6929 - val_loss: 0.8731
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 11ms/step - accuracy: 0.7634 - loss: 0.6777 - val_accuracy: 0.6930 - val_loss: 0.8955
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 11ms/step - accuracy: 0.7717 - loss: 0.6505 - val_accuracy: 0.7003 - val_loss: 0.8872
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.7803 - loss: 0.6194 - val_accuracy: 0.6957 - val_loss: 0.8936

# %%
# Optimized 

cnn_optimized = models.Sequential(
    [
        # First Convolution 
        layers.Conv2D(filters = 32, kernel_size = (3,3), activation = "relu", padding = "same", input_shape = (32, 32, 3)),
        layers.BatchNormalization(),
        layers.Conv2D(filters = 32, kernel_size = (3,3), activation = "relu", padding = "same" ),
        layers.MaxPooling2D((2,2)),
        layers.BatchNormalization(),

        # Second Convolution 
        layers.Conv2D(filters = 64, kernel_size = (3, 3), activation = "relu", padding = "same"),
        layers.Conv2D(filters = 64, kernel_size = (3,3), activation = "relu", padding = "same"),
        layers.MaxPooling2D((2,2)),
        layers.BatchNormalization(),

        # Dense Layers 
        layers.Flatten(),
        layers.Dense(512, activation = 'relu'),
        layers.Dropout(0.5),
        layers.Dense(128, activation = 'relu'),
        layers.Dropout(0.5), 
        layers.Dense(10, activation = 'softmax')
    ]
)

cnn_optimized.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

data_augmentation = tf.keras.Sequential(
    [
        layers.RandomFlip("horizontal"), 
        layers.RandomRotation(0.1), 
        layers.RandomZoom(0.1)
    ]
)

history = cnn_optimized.fit(
    data_augmentation(X_train), 
    y_train, 
    batch_size = 64,
    epochs = 20, 
    validation_split = 0.2,
    callbacks = [
        tf.keras.callbacks.EarlyStopping(patience = 5, restore_best_weights = True),
        tf.keras.callbacks.ReduceLROnPlateau(factor = 0.2, patience = 3)
    ]
)

test_loss, test_accuracy = cnn_optimized.evaluate(X_test, y_test)
print(test_loss, test_accuracy)

plt.figure()

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label = 'Training Accuracy'),
plt.plot(history.history['val_accuracy'], label = 'Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Model Accuracy')


plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label = 'Training Loss'),
plt.plot(history.history['val_loss'], label = 'Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Model Loss')
plt.tight_layout()
plt.show()
# Out:
# Epoch 1/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 57s 82ms/step - accuracy: 0.2542 - loss: 2.1759 - val_accuracy: 0.4190 - val_loss: 1.6067 - learning_rate: 0.0010
# Epoch 2/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 50s 80ms/step - accuracy: 0.4345 - loss: 1.5657 - val_accuracy: 0.5231 - val_loss: 1.3572 - learning_rate: 0.0010
# Epoch 3/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 50s 80ms/step - accuracy: 0.5218 - loss: 1.3459 - val_accuracy: 0.5536 - val_loss: 1.2794 - learning_rate: 0.0010
# Epoch 4/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 53s 85ms/step - accuracy: 0.5889 - loss: 1.1778 - val_accuracy: 0.5819 - val_loss: 1.2191 - learning_rate: 0.0010
# Epoch 5/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 55s 87ms/step - accuracy: 0.6297 - loss: 1.0621 - val_accuracy: 0.5945 - val_loss: 1.1791 - learning_rate: 0.0010
# Epoch 6/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 59s 94ms/step - accuracy: 0.6616 - loss: 0.9770 - val_accuracy: 0.6339 - val_loss: 1.0904 - learning_rate: 0.0010
# Epoch 7/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 59s 94ms/step - accuracy: 0.7031 - loss: 0.8631 - val_accuracy: 0.6619 - val_loss: 0.9873 - learning_rate: 0.0010
# Epoch 8/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 60s 96ms/step - accuracy: 0.7285 - loss: 0.7876 - val_accuracy: 0.6281 - val_loss: 1.1561 - learning_rate: 0.0010
# Epoch 9/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 61s 97ms/step - accuracy: 0.7558 - loss: 0.7130 - val_accuracy: 0.6398 - val_loss: 1.1162 - learning_rate: 0.0010
# Epoch 10/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 55s 87ms/step - accuracy: 0.7856 - loss: 0.6237 - val_accuracy: 0.6696 - val_loss: 1.0156 - learning_rate: 0.0010
# Epoch 11/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 54s 86ms/step - accuracy: 0.8297 - loss: 0.4943 - val_accuracy: 0.6911 - val_loss: 0.9736 - learning_rate: 2.0000e-04
# Epoch 12/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 55s 88ms/step - accuracy: 0.8672 - loss: 0.3920 - val_accuracy: 0.6983 - val_loss: 1.0092 - learning_rate: 2.0000e-04
# Epoch 13/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 58s 92ms/step - accuracy: 0.8800 - loss: 0.3502 - val_accuracy: 0.6978 - val_loss: 1.0486 - learning_rate: 2.0000e-04
# Epoch 14/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 56s 89ms/step - accuracy: 0.8906 - loss: 0.3181 - val_accuracy: 0.7015 - val_loss: 1.0815 - learning_rate: 2.0000e-04
# Epoch 15/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 55s 88ms/step - accuracy: 0.9061 - loss: 0.2740 - val_accuracy: 0.7051 - val_loss: 1.0836 - learning_rate: 4.0000e-05
# Epoch 16/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 61s 98ms/step - accuracy: 0.9103 - loss: 0.2669 - val_accuracy: 0.7057 - val_loss: 1.0991 - learning_rate: 4.0000e-05
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7127 - loss: 0.9905
# 1.0129960775375366 0.7060999870300293

# %% [markdown]
# # RNN

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from tensorflow.keras.datasets import imdb 
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Embedding, SimpleRNN, LSTM, Dense
from tensorflow.keras.optimizers import Adam

# %%
# Load and Preprocess Data 

num_words = 100000
maxlen = 200

(X_train, y_train), (X_test, y_test) = imdb.load_data()
X_train = pad_sequences(X_train, maxlen = maxlen)
X_test = pad_sequences(X_test, maxlen = maxlen)

val_samples = 10000

X_val = X_train[:val_samples]
y_val = y_train[:val_samples]
X_train = X_train[val_samples:]
y_train = y_train[val_samples:]


max_words = 10000
rnn_model = Sequential(
    [
        Embedding(10000, 50, input_length = maxlen),
        SimpleRNN(64),
        Dense(1, activation = 'sigmoid')
    ]
)

rnn_model.compile(optimizer = Adam(learning_rate = 0.001), loss = 'binary_crossentropy', metrics = ['accuracy'])

# Build and compile LSTM model

lstm_model = Sequential(
    [
         Embedding(10000, 50, input_length = maxlen),
         LSTM(64),
         Dense(1, activation = 'sigmoid')
    ]
)

lstm_model.compile(optimizer = Adam(learning_rate = 0.001), loss = "binary_crossentropy", metrics = ['accuracy'])

history_rnn = rnn_model.fit(X_train, y_train, validation_data = (X_val, y_val), epochs = 5, batch_size = 32)
history_lstm = lstm_model.fit(X_train, y_train, validation_data = (X_val, y_val), epochs = 5, batch_size = 32)


rnn_test_loss, rnn_test_accuracy = rnn_model.evaluate(X_test, y_test)
lstm_test_loss, lstm_test_accuracy = lstm_model.evaluate(X_test, y_test)

print(f"RNN Test Accuracy: {rnn_test_accuracy:.4f}")
print(f"LSTM Test Accuracy: {lstm_test_accuracy:.4f}")

plt.figure()

plt.subplot(2,2,1)
plt.plot(history_rnn.history['accuracy'])
plt.plot(history_rnn.history['val_accuracy'])
plt.title('RNN Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()


plt.subplot(2,2,2)
plt.plot(history_rnn.history['loss'])
plt.plot(history_rnn.history['val_loss'])
plt.title('RNN Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.subplot(2,2,3)
plt.plot(history_lstm.history['accuracy'])
plt.plot(history_lstm.history['val_accuracy'])
plt.title('LSTM Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()


plt.subplot(2,2,4)
plt.plot(history_lstm.history['loss'])
plt.plot(history_lstm.history['val_loss'])
plt.title('LSTM Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/5
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[48], line 41
#      31 lstm_model = Sequential(
#      32     [
#      33          Embedding(10000, 50, input_length = maxlen),
#    (...)
#      36     ]
#      37 )
#      39 lstm_model.compile(optimizer = Adam(learning_rate = 0.001), loss = "binary_crossentropy", metrics = ['accuracy'])
# ---> 41 history_rnn = rnn_model.fit(X_train, y_train, validation_data = (X_val, y_val), epochs = 5, batch_size = 32)
#      42 history_lstm = lstm_model.fit(X_train, y_train, validation_data = (X_val, y_val), epochs = 5, batch_size = 32)
#      45 rnn_test_loss, rnn_test_accuracy = rnn_model.evaluate(X_test, y_test)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node sequential_19_1/embedding_6_1/GatherV2 defined at (most recent call last):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\runpy.py", line 196, in _run_module_as_main
#
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\runpy.py", line 86, in _run_code
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ipykernel_launcher.py", line 18, in <module>
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ipykernel\kernelapp.py", line 739, in start
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tornado\platform\asyncio.py", line 205, in start
#
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\asyncio\base_events.py", line 603, in run_forever
#
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\asyncio\base_events.py", line 1909, in _run_once
#
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\asyncio\events.py", line 80, in _run
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#
#   File "C:\Users\swaro\AppData\Local\Temp\ipykernel_55908\1597405852.py", line 41, in <module>
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\backend\tensorflow\trainer.py", line 320, in fit
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\backend\tensorflow\trainer.py", line 121, in one_step_on_iterator
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\backend\tensorflow\trainer.py", line 108, in one_step_on_data
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\backend\tensorflow\trainer.py", line 51, in train_step
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\layers\layer.py", line 899, in __call__
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\ops\operation.py", line 46, in __call__
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\utils\traceback_utils.py", line 156, in error_handler
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\models\sequential.py", line 213, in call
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\models\functional.py", line 182, in call
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\ops\function.py", line 171, in _run_through_graph
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\models\functional.py", line 584, in call
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\layers\layer.py", line 899, in __call__
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\ops\operation.py", line 46, in __call__
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\utils\traceback_utils.py", line 156, in error_handler
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\layers\core\embedding.py", line 140, in call
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\ops\numpy.py", line 5206, in take
#
#   File "C:\Users\swaro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\backend\tensorflow\numpy.py", line 2029, in take
#
# indices[27,148] = 17720 is not in [0, 10000)
# 	 [[{{node sequential_19_1/embedding_6_1/GatherV2}}]] [Op:__inference_one_step_on_iterator_491307]
